# %% [markdown]
# # GAP Optimisation using XPOT
#
# This is a simple example of optimising parameters for GAP models using the XPOT package. We start by initialising an instance of the `GAP` class, which reads in the input file and sets up everything required for the GAP model to be fitted by the optimiser. The input file can be found in the examples folder.

# %%
from xpot.models.gap import GAP

mlip = GAP("gap_input.hjson")

# %% [markdown]
# Now that the ML potential object is set up, we can inspect the parameters that have been defined for optimisation in the input file, and check that those have been correctly parsed by the `GAP` class. The second cell prints the entire parameter dictionary, and will be used throughout the optimisation and updated with the new parameter values for each iteration.

# %%
print(mlip.optimisation_space)
# Out:
# {(('gap', 'distance_Nb', 'cutoff'),): Real(low=4, high=7, prior='uniform', transform='identity')}

# %%
print(mlip.gap_total)
# Out:
# {'at_file': '/u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz', 'gap': OrderedDict([('distance_Nb', OrderedDict([('order', 2), ('f0', 0), ('cutoff', 'skopt.space.Real(4,7)'), ('n_sparse', 15), ('delta', 2), ('config_type_n_sparse', ''), ('sparse_method', 'random'), ('mark_sparse_atoms', 'F'), ('add_species', 'T'), ('covariance_type', 'gaussian'), ('theta_uniform', 1)]))]), 'core_param_file': '', 'core_ip_args': '', 'energy_parameter_name': 'energy', 'local_property_parameter_name': 'local_property', 'force_parameter_name': 'forces', 'virial_parameter_name': 'virial', 'hessian_parameter_name': 'hessian', 'config_type_parameter_name': 'config_type', 'sigma_parameter_name': 'sigma', 'force_mask_parameter_name': 'force_mask', 'parameter_name_prefix': '', 'gap_file': 'gap.xml', 'verbosity': 'NORMAL', 'template_file': '', 'sparsify_only_no_fit': 'F', 'e0': '0.0', 'local_property0': '0.0', 'e0_offset': '0.0', 'e0_method': 'isolated', 'default_sigma': [0.002, 0.2, 0.2, 0], 'sparse_jitter': '1.0e-8', 'hessian_delta': '1.0e-2', 'config_type_kernel_regularisation': '', 'config_type_sigma energy': '', 'config_type_sigma force': '', 'config_type_sigma virial': '', 'config_type_sigma hessian': '', 'kernel_regularisation_is_per_atom': 'T', 'sigma_per_atom': 'T', 'do_copy_atoms_file': 'T', 'do_copy_at_file': 'T', 'sparse_separate_file': 'T', 'sparse_use_actual_gpcov': 'F', 'rnd_seed': '1', 'openmp_chunk_size': '10000', 'do_ip_timing': 'F'}

# %% [markdown]
# Now that the ML potential object is set up, we can import and initialise the optimiser which wraps around the ML potential object. the kwargs dictionary passes optimization parameters to the optimizer, possible values and their defaults are documented at [`scikit_optimize.Optimizer`](https://scikit-optimize.github.io/dev/modules/generated/skopt.Optimizer.html#skopt.Optimizer).

# %%
from xpot.optimiser import NamedOptimiser

kwargs = {
        "n_initial_points": 5,
        }

opt = NamedOptimiser(mlip.optimisation_space, mlip.sweep_path, kwargs)
# Out:
# Initialised CSV Files

# %% [markdown]
# We limit the number of iterations to 10, and perform 10 fits and record their loss values. By using `optimiser.run_optimisation` we run a fit and evaluate all of the parameters & results produced from a single iteration.

# %%
n_calls = 10

while opt.iter <= n_calls:
    opt.run_optimisation(mlip.fit, path = mlip.sweep_path)
# Out:
# libAtoms::Hello World: 2024-02-15 11:51:33
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42693474
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=6.3896289605806995 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=6.3896289605806995 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=6.3896289605806995 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=6.3896289605806995 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        435276
# Number of partial derivatives of descriptors: 7834968
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 435276 memory 3482 KB
# Descriptor 1 :: xPrime 1 7834968 memory 62 MB
# Subtotal 66 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 67 MB
# Peak2 4805 KB
# PEAK  67 MB
#
# Free system memory  82 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 6.2701859999999998 cpu secs, .27912027295678854 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 6.2706749999999989 cpu secs, .27937472937628627 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .12999999999152578E-004 cpu secs, .13780780136585236E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 6.2707959999999998 cpu secs, .27949819993227720 wall clock secs.
# TIMER: Build linear system                                done in .18146699999999960 cpu secs, .89973052963614464E-002 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .15711100000000044 cpu secs, .72047412395477295E-002 wall clock secs.
# TIMER: GP sparsify                                        done in 6.7721079999999994 cpu secs, .32098303688690066 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:51:35
# libAtoms::Finalise: Bye-Bye!
# Iteration 1 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:52:24
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42744382
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=4.550304369598491 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=4.550304369598491 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=4.550304369598491 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=4.550304369598491 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        164826
# Number of partial derivatives of descriptors: 2966868
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 164826 memory 1318 KB
# Descriptor 1 :: xPrime 1 2966868 memory 23 MB
# Subtotal 25 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 26 MB
# Peak2 4805 KB
# PEAK  26 MB
#
# Free system memory  82 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 3.2846799999999998 cpu secs, .14266780996695161 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 3.2847119999999999 cpu secs, .14269595500081778 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .12999999999152578E-004 cpu secs, .12747943401336670E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 3.2847959999999996 cpu secs, .14278250187635422 wall clock secs.
# TIMER: Build linear system                                done in .25799999999964740E-003 cpu secs, .26299385353922844E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .22384999999999966 cpu secs, .11492840945720673E-001 wall clock secs.
# TIMER: GP sparsify                                        done in 3.6100330000000005 cpu secs, .17904955567792058 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:52:25
# libAtoms::Finalise: Bye-Bye!
# Iteration 2 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:52:51
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42771773
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=6.339073000818308 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=6.339073000818308 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=6.339073000818308 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=6.339073000818308 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        422908
# Number of partial derivatives of descriptors: 7612344
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 422908 memory 3383 KB
# Descriptor 1 :: xPrime 1 7612344 memory 60 MB
# Subtotal 64 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 65 MB
# Peak2 4805 KB
# PEAK  65 MB
#
# Free system memory  82 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 4.7281300000000002 cpu secs, .20228523900732398 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 4.7283619999999988 cpu secs, .20251430571079254 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .13000000000928935E-004 cpu secs, .12503005564212799E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 4.7284729999999993 cpu secs, .20262848213315010 wall clock secs.
# TIMER: Build linear system                                done in .21949000000001107E-001 cpu secs, .51402207463979721E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .14262800000000020 cpu secs, .64193638972938061E-002 wall clock secs.
# TIMER: GP sparsify                                        done in 5.0703939999999994 cpu secs, .23564873728901148 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:52:53
# libAtoms::Finalise: Bye-Bye!
# Iteration 3 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:53:47
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42827585
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=5.7905504738394615 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=5.7905504738394615 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=5.7905504738394615 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=5.7905504738394615 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        325142
# Number of partial derivatives of descriptors: 5852556
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 325142 memory 2601 KB
# Descriptor 1 :: xPrime 1 5852556 memory 46 MB
# Subtotal 49 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 50 MB
# Peak2 4805 KB
# PEAK  50 MB
#
# Free system memory  81 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 4.8777780000000002 cpu secs, .21376081230118871 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 4.8971769999999992 cpu secs, .21393804624676704 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .14000000000180535E-004 cpu secs, .13895798474550247E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 4.8972660000000001 cpu secs, .21402935776859522 wall clock secs.
# TIMER: Build linear system                                done in .23022000000000986E-001 cpu secs, .10119946673512459E-002 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .13677799999999962 cpu secs, .59780618175864220E-002 wall clock secs.
# TIMER: GP sparsify                                        done in 5.2387300000000003 cpu secs, .24716811534017324 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:53:49
# libAtoms::Finalise: Bye-Bye!
# Iteration 4 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:54:34
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42874828
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=5.337498258560774 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=5.337498258560774 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=5.337498258560774 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=5.337498258560774 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        264978
# Number of partial derivatives of descriptors: 4769604
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 264978 memory 2119 KB
# Descriptor 1 :: xPrime 1 4769604 memory 38 MB
# Subtotal 40 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 41 MB
# Peak2 4805 KB
# PEAK  41 MB
#
# Free system memory  81 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 6.0578399999999988 cpu secs, .29354597767814994 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 6.0580470000000002 cpu secs, .29375217389315367 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .15999999998683734E-004 cpu secs, .16110949218273163E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 6.0581410000000000 cpu secs, .29384782910346985 wall clock secs.
# TIMER: Build linear system                                done in .45300000000025875E-003 cpu secs, .45492779463529587E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .16046599999999955 cpu secs, .62793469987809658E-002 wall clock secs.
# TIMER: GP sparsify                                        done in 6.4042290000000008 cpu secs, .32872772403061390 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:54:36
# libAtoms::Finalise: Bye-Bye!
# Iteration 5 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:55:16
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42916293
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        100704
# Number of partial derivatives of descriptors: 1812672
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 100704 memory 805 KB
# Descriptor 1 :: xPrime 1 1812672 memory 14 MB
# Subtotal 15 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 16 MB
# Peak2 4805 KB
# PEAK  16 MB
#
# Free system memory  81 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 2.6753140000000002 cpu secs, .11749384831637144 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 2.6753469999999999 cpu secs, .11752467881888151 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .15999999999571912E-004 cpu secs, .15226658433675766E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 2.6754519999999999 cpu secs, .11763207800686359 wall clock secs.
# TIMER: Build linear system                                done in .37399999999987443E-003 cpu secs, .37524709478020668E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .24047499999999999 cpu secs, .10986694134771824E-001 wall clock secs.
# TIMER: GP sparsify                                        done in 3.0134880000000006 cpu secs, .15334030007943511 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:55:17
# libAtoms::Finalise: Bye-Bye!
# Iteration 6 written to parameters.csv
# /u/vld/scat7402/anaconda3/envs/xpot-dev/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# libAtoms::Hello World: 2024-02-15 11:55:41
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42941079
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=4.0 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        100704
# Number of partial derivatives of descriptors: 1812672
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 100704 memory 805 KB
# Descriptor 1 :: xPrime 1 1812672 memory 14 MB
# Subtotal 15 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 16 MB
# Peak2 4805 KB
# PEAK  16 MB
#
# Free system memory  81 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 4.1888500000000004 cpu secs, .19249865133315325 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 4.1888810000000003 cpu secs, .19252706179395318 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .12000000000789157E-004 cpu secs, .12668780982494354E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 4.1889669999999999 cpu secs, .19261559098958969 wall clock secs.
# TIMER: Build linear system                                done in .18989999999998730E-002 cpu secs, .68060820922255516E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .23779000000000039 cpu secs, .11041247751563787E-001 wall clock secs.
# TIMER: GP sparsify                                        done in 4.5282400000000003 cpu secs, .22881643706932664 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:55:42
# libAtoms::Finalise: Bye-Bye!
# Iteration 7 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:56:07
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# ...
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 2.1317450000000000 cpu secs, .93751213047653437E-001 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 2.1317819999999998 cpu secs, .93784886877983809E-001 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .11999999999900979E-004 cpu secs, .12092757970094681E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 2.1318560000000000 cpu secs, .93862003181129694E-001 wall clock secs.
# TIMER: Build linear system                                done in .23302000000001044E-001 cpu secs, .33678021281957626E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .21906999999999943 cpu secs, .10959490202367306E-001 wall clock secs.
# TIMER: GP sparsify                                        done in 2.4774629999999993 cpu secs, .13044955395162106 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:56:08
# libAtoms::Finalise: Bye-Bye!
# Iteration 8 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:56:35
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 42995518
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=4.1958220270522455 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=4.1958220270522455 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=4.1958220270522455 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=4.1958220270522455 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        119990
# Number of partial derivatives of descriptors: 2159820
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 119990 memory 959 KB
# Descriptor 1 :: xPrime 1 2159820 memory 17 MB
# Subtotal 18 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 19 MB
# Peak2 4805 KB
# PEAK  19 MB
#
# Free system memory  81 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 2.6353450000000000 cpu secs, .11398418294265866 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 2.6353779999999998 cpu secs, .11401423020288348 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .15000000000320313E-004 cpu secs, .14927703887224197E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 2.6354619999999995 cpu secs, .11410114914178848 wall clock secs.
# TIMER: Build linear system                                done in .36199999999997345E-003 cpu secs, .36497879773378372E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .23804200000000009 cpu secs, .11110682971775532E-001 wall clock secs.
# TIMER: GP sparsify                                        done in 3.0059350000000000 cpu secs, .15809605689719319 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:56:36
# libAtoms::Finalise: Bye-Bye!
# Iteration 9 written to parameters.csv
# libAtoms::Hello World: 2024-02-15 11:57:05
# libAtoms::Hello World: git version  https://github.com/libAtoms/QUIP,v0.9.14-dirty
# libAtoms::Hello World: QUIP_ARCH    linux_x86_64_gfortran_openmp
# libAtoms::Hello World: compiled on  Jun 15 2023 at 19:28:03
# libAtoms::Hello World: OpenMP parallelisation with 24 threads
# WARNING: libAtoms::Hello World: environment variable OMP_STACKSIZE not set explicitly. The default value - system and compiler dependent - may be too small for some applications.
# libAtoms::Hello World: Random Seed = 43025419
# libAtoms::Hello World: global verbosity = 0
#
# Calls to system_timer will do nothing by default
#
#
# ================================ Input parameters ==============================
#
# config_file =
# atoms_filename = //MANDATORY//
# at_file = /u/vld/scat7402/Documents/xpot-v2/examples/gap_C_XYZ/bulk_cryst_train.xyz
# gap = "distance_Nb order=2 f0=0 cutoff=4.186318733016118 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy"
# e0 = 0.0
# local_property0 = 0.0
# e0_offset = 0.0
# e0_method = isolated
# default_kernel_regularisation = //MANDATORY//
# default_sigma = "0.002 0.2 0.2 0"
# default_kernel_regularisation_local_property = 0.001
# default_local_property_sigma = 0.001
# sparse_jitter = 1.0e-8
# hessian_displacement = 1.0e-2
# hessian_delta = 1.0e-2
# baseline_param_filename = quip_params.xml
# core_param_file = quip_params.xml
# baseline_ip_args =
# core_ip_args =
# energy_parameter_name = energy
# local_property_parameter_name = local_property
# force_parameter_name = forces
# virial_parameter_name = virial
# stress_parameter_name = stress
# hessian_parameter_name = hessian
# config_type_parameter_name = config_type
# kernel_regularisation_parameter_name = sigma
# sigma_parameter_name = sigma
# force_mask_parameter_name = force_mask
# local_property_mask_parameter_name = local_property_mask
# parameter_name_prefix =
# config_type_kernel_regularisation =
# config_type_sigma =
# kernel_regularisation_is_per_atom = T
# sigma_per_atom = T
# do_copy_atoms_file = T
# do_copy_at_file = T
# sparse_separate_file = T
# sparse_use_actual_gpcov = F
# gap_file = gap.xml
# gp_file = gap_new.xml
# verbosity = NORMAL
# rnd_seed = 1
# openmp_chunk_size = 10000
# do_ip_timing = F
# template_file = template.xyz
# sparsify_only_no_fit = F
# dryrun = F
# condition_number_norm =
# linear_system_dump_file =
# mpi_blocksize_rows = 0
# mpi_blocksize_cols = 100
# mpi_print_all = F
# export_covariance = F
#
# ========================================  ======================================
#
#
# ============== Gaussian Approximation Potentials - Database fitting ============
#
#
# Initial parsing of command line arguments finished.
# Found 1 GAPs.
# Descriptors have been parsed
# XYZ file read
# Old GAP: {distance_Nb order=2 f0=0 cutoff=4.186318733016118 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F add_species=T covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy}
# New GAP: {distance_Nb order=2 f0=0 cutoff=4.186318733016118 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }}
# Multispecies support added where requested
#
# ===================== Report on number of descriptors found ====================
#
# ---------------------------------------------------------------------
# Descriptor 1: distance_Nb order=2 f0=0 cutoff=4.186318733016118 n_sparse=15 delta=2 sparse_method=random mark_sparse_atoms=F               covariance_type=gaussian theta_uniform=1 energy_parameter_name=energy Z={6 6 }
# Number of descriptors:                        119064
# Number of partial derivatives of descriptors: 2143152
#
# ========================================  ======================================
#
#
# ========================= Memory Estimate (per process) ========================
#
# Descriptors
# Descriptor 1 :: x 1 119064 memory 952 KB
# Descriptor 1 :: xPrime 1 2143152 memory 17 MB
# Subtotal 18 MB
#
# Covariances
# yY 15 10000 memory 1200 KB * 2
# yy 15 15 memory 1800  B
# A 15 10015 memory 1201 KB * 2
# Subtotal 4805 KB
#
# Peak1 19 MB
# Peak2 4805 KB
# PEAK  19 MB
#
# Free system memory  81 GB
# Total system memory 134 GB
#
# ========================================  ======================================
#
# WARNING: Both e0 and e0_offset has been specified. That means your atomic energy is e0 + e0_offset
#
# ========== Report on number of target properties found in training XYZ: ========
#
# Number of target energies (property name: energy) found: 400
# Number of target local_properties (property name: local_property) found: 0
# Number of target forces (property name: forces) found: 7200
# Number of target virials (property name: virial) found: 2400
# Number of target Hessian eigenvalues (property name: hessian) found: 0
#
# ================================= End of report ================================
#
#
# ===== Report on per-configuration/per-atom sigma (error parameter) settings ====
#
# Number of per-configuration setting of energy_sigma found:     0
# Number of per-configuration setting of force_sigma found:      0
# Number of per-configuration setting of virial_sigma found:     0
# Number of per-configuration setting of hessian_sigma found:    0
# Number of per-configuration setting of local_propery_sigma found:0
# Number of per-atom setting of force_atom_sigma found:          0
# Number of per-component setting of force_component_sigma found:          0
# Number of per-component setting of virial_component_sigma found:          0
#
# ================================= End of report ================================
#
# Cartesian coordinates transformed to descriptors
# Started sparse covariance matrix calculation of coordinate 1
#
# Finished sparse covariance matrix calculation of coordinate 1
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1_sparse  done in 2.3757410000000005 cpu secs, .10296832583844662 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_Coordinate1         done in 2.3757729999999997 cpu secs, .10299778264015913 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse_FunctionValues      done in .15999999999571912E-004 cpu secs, .15435274690389633E-004 wall clock secs.
# TIMER: gpFull_covarianceMatrix_sparse                     done in 2.3758770000000000 cpu secs, .10310438927263021 wall clock secs.
# TIMER: Build linear system                                done in .23400999999999783E-001 cpu secs, .37172995507717133E-003 wall clock secs.
# Using LAPACK to solve QR
# TIMER: Solve linear system                                done in .22366699999999984 cpu secs, .11269054841250181E-001 wall clock secs.
# TIMER: GP sparsify                                        done in 2.7481800000000005 cpu secs, .14376179501414299 wall clock secs.
#
# libAtoms::Finalise: 2024-02-15 11:57:06
# libAtoms::Finalise: Bye-Bye!
# Iteration 10 written to parameters.csv

# %% [markdown]
# Finally, after we have completed the optimisation across the desired number of iterations (or achieved the desired loss value), we produce the final tables of the errors and parameters from the optimisation sweep.

# %%
opt.tabulate_final_results(mlip.sweep_path)

# %%
from IPython.display import Markdown, display

display(Markdown("/u/vld/scat7402/Documents/xpot-v2/examples/opt_GAP/test_GAP/parameters_final"))
# Out:
# |   iteration |     loss |   gap distance_Nb cutoff |
# |-------------|----------|--------------------------|
# |           1 | 450.208  |                  6.38963 |
# |           2 |  97.8792 |                  4.5503  |
# |           3 | 364.799  |                  6.33907 |
# |           4 | 228.37   |                  5.79055 |
# |           5 | 178.539  |                  5.3375  |
# |           6 |  96.1731 |                  4       |
# |           7 |  96.1731 |                  4       |
# |           8 |  93.3704 |                  4.19819 |
# |           9 |  92.8792 |                  4.19582 |
# |          10 |  92.7703 |                  4.18632 |

# %%
display(Markdown("/u/vld/scat7402/Documents/xpot-v2/examples/opt_GAP/test_GAP/atomistic_errors_final"))
# Out:
# |   Iteration |   Train Δ Energy |   Test Δ Energy |   Train Δ Force |   Test Δ Force |
# |-------------|------------------|-----------------|-----------------|----------------|
# |           1 |         1.72092  |        93.5002  |         19.7919 |        74.8614 |
# |           2 |         0.568031 |        10.6217  |         19.9979 |       108.834  |
# |           3 |         1.76868  |        74.901   |         20.1714 |        70.2653 |
# |           4 |         1.07757  |        42.3083  |         10.7605 |        84.5899 |
# |           5 |         0.854866 |        30.3342  |         12.3881 |        92.5039 |
# |           6 |         0.705469 |        10.0987  |         24.3064 |       109.271  |
# |           7 |         0.705469 |        10.0987  |         24.3064 |       109.271  |
# |           8 |         0.538924 |         8.76869 |         24.5234 |       115.421  |
# |           9 |         0.762753 |         9.95746 |         18.8444 |       104.201  |
# |          10 |         0.571366 |         8.86989 |         23.5309 |       113.353  |
